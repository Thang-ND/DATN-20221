# %%
import pandas as pd
import json
from datetime import datetime
import pandas as pd
import sys
sys.path.insert(0, "..")
from mypackage.MatchingSystem import MatchingSystem
from mypackage.PreprocessData import PreprocessData

# %%
createdDate = datetime.now()
matchingSystem = MatchingSystem()
preprocess = PreprocessData()

# %%
df_origin = pd.read_json('./Data.json')

# %%
data = matchingSystem.pipelineMatching(df_origin)
# Out:
# name                	name                	1.0
# url                 	url                 	1.0
# url_img             	url_img             	1.0
# rom                 	rom                 	1.0
# ram                 	ram                 	1.0
# ram                 	ram                 	1.0
# ram                 	ram                 	1.0
# color               	color               	1.0
# price               	price               	1.0

# %%
newDf = preprocess.extractRomFromName(data)

# %%
newDf = preprocess.extractRamFromName(newDf)
newDf = preprocess.preprocessData(newDf, status=0)
newDf = preprocess.preprocessColor(newDf)

# %%
newDf
# Out:
#                 name                                                url  \
# 0     IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...
# 1     IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...
# 2     IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...
# 3     IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...
# 4     IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...
# ...              ...                                                ...
# 1387   IPAD PRO 12.9  https://onewaymobile.vn/ipad-pro-moi/may-tinh-...
# 1388   IPAD PRO 12.9  https://onewaymobile.vn/ipad-pro-moi/may-tinh-...
# 1389   IPAD PRO 12.9  https://onewaymobile.vn/ipad-pro-moi/may-tinh-...
# 1390   IPAD PRO 12.9  https://onewaymobile.vn/ipad-pro-moi/may-tinh-...
# 1391   IPAD PRO 12.9  https://onewaymobile.vn/ipad-pro-moi/may-tinh-...
#
#           ram  rom     price                createdDate  color  status  \
# 0           4   64   9990000 2022-12-26 19:48:41.443815  BLACK       0
# 1           4   64   9990000 2022-12-26 19:48:41.443815  WHITE       0
# 2           4   64   9990000 2022-12-26 19:48:41.443815    RED       0
# 3           4  128  10990000 2022-12-26 19:48:41.443815  BLACK       0
# 4           4  128  10990000 2022-12-26 19:48:41.443815  WHITE       0
# ...       ...  ...       ...                        ...    ...     ...
# 1387  unknown  128  31990000 2022-12-26 19:48:41.443815   GRAY       0
# 1388  unknown  128  31990000 2022-12-26 19:48:41.443815  WHITE       0
# 1389  unknown  128  31990000 2022-12-26 19:48:41.443815   GRAY       0
# 1390  unknown  128  28290000 2022-12-26 19:48:41.443815  WHITE       0
# 1391  unknown  128  28290000 2022-12-26 19:48:41.443815   GRAY       0
#
#       url_img
# 0     unknown
# 1     unknown
# 2     unknown
# 3     unknown
# 4     unknown
# ...       ...
# 1387  unknown
# 1388  unknown
# 1389  unknown
# 1390  unknown
# 1391  unknown
#
# [1392 rows x 9 columns]

# %%
len(newDf.drop_duplicates())
# Out:
# 282

# %%
newDf.drop_duplicates(inplace=True)

# %%
newDf['store'] = 'onewaymobile'

# %%
newDf.head()
# Out:
#              name                                                url ram  rom  \
# 0  IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...   4   64
# 1  IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...   4   64
# 2  IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...   4   64
# 3  IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...   4  128
# 4  IPHONE SE 2022  https://onewaymobile.vn/iphone-se/dien-thoai-a...   4  128
#
#       price                createdDate  color  status  url_img         store
# 0   9990000 2022-12-26 19:48:41.443815  BLACK       0  unknown  onewaymobile
# 1   9990000 2022-12-26 19:48:41.443815  WHITE       0  unknown  onewaymobile
# 2   9990000 2022-12-26 19:48:41.443815    RED       0  unknown  onewaymobile
# 3  10990000 2022-12-26 19:48:41.443815  BLACK       0  unknown  onewaymobile
# 4  10990000 2022-12-26 19:48:41.443815  WHITE       0  unknown  onewaymobile

# %%
newDf.to_csv('../../datamatching/data/onewaymobile-phone.csv')
