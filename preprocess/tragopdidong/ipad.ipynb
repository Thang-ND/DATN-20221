# %%
import pandas as pd
import json
from datetime import datetime
import pandas as pd
import sys
sys.path.insert(0, "..")
from mypackage.MatchingSystem import MatchingSystem
from mypackage.PreprocessData import PreprocessData

# %%
createdDate = datetime.now()
matchingSystem = MatchingSystem()
preprocess = PreprocessData()

# %%
df_origin = pd.read_json('./ipad.json')

# %%
df_origin.head()
# Out:
#                                  name  \
# 0  iPad 4 Wifi/4G 64GB Mới 95% -> 99%
# 1  iPad 2 Wifi/3G 16GB Mới 95% -> 99%
# 2  iPad 4 Wifi/4G 16GB Mới 95% -> 99%
# 3  iPad 3 Wifi/4G 16GB Mới 95% -> 99%
# 4     iPad 3 Wifi 16GB Mới 95% -> 99%
#
#                                                price  \
# 0  \r\n                                        5,...
# 1  \r\n                                        2,...
# 2  \r\n                                        3,...
# 3  \r\n                                        2,...
# 4  \r\n                                        3,...
#
#                                              url_img  \
# 0  [http://tragopdidong.vn/img/h360/ipad-4-wifi-4...
# 1  [http://tragopdidong.vn/img/h360/ipad-2-wifi-3...
# 2  [http://tragopdidong.vn/img/h360/ipad-4-wifi-4...
# 3  [http://tragopdidong.vn/img/h360/ipad-3-wifi-4...
# 4  [http://tragopdidong.vn/img/h360/ipad-3-wifi-1...
#
#                                                 link  \
# 0  http://tragopdidong.vn/ipad-4-wifi-4g-64gb-moi...
# 1  http://tragopdidong.vn/ipad-2-wifi-3g-16gb-moi...
# 2  http://tragopdidong.vn/ipad-4-wifi-4g-16gb-moi...
# 3  http://tragopdidong.vn/ipad-3-wifi-4g-16gb-moi...
# 4  http://tragopdidong.vn/ipad-3-wifi-16gb-moi-95...
#
#                                                 data
# 0  [<div id="myTabContent" class="tab-content">\r...
# 1  [<div id="myTabContent" class="tab-content">\r...
# 2  [<div id="myTabContent" class="tab-content">\r...
# 3  [<div id="myTabContent" class="tab-content">\r...
# 4  [<div id="myTabContent" class="tab-content">\r...

# %%
test = pd.read_html(df_origin['data'].iloc[0][0])

# %%
test[0].T
# Out:
#                  0                            1         2   \
# 0  Thông tin cơ bản  Hãng sản xuất (Manufacture)  Màn hình
# 1  Thông tin cơ bản                        Apple  Màn hình
#
#                                                   3                   4   \
# 0                              Loại màn hình cảm ứng  Công nghệ màn hình
# 1  Màn hình cảm ứng điện dung (Capacitive Touchsc...                 IPS
#
#                        5                                   6    7   \
# 0  Độ lớn màn hình (inch)  Độ phân giải màn hình (Resolution)  CPU
# 1                9.7 inch                         2048 x 1536  CPU
#
#                       8                   9   ...                      21  \
# 0    Loại CPU (CPU Type)  Tốc độ (CPU Speed)  ...  Kết nối không dây khác
# 1  Apple A6X (dual core)             1.30Ghz  ...  • Bluetooth 4.0  • GPS
#
#                                        22        23  \
# 0                  Cổng giao tiếp (Ports)  Cổng USB
# 1  • Headphone  • Microphone  • Lightning       • -
#
#                           24                                              25  \
# 0         Tính năng đặc biệt                                  Tính năng khác
# 1  • Camera  • SIM card tray  - Camera iSight 5.0 megapixel - Retina display
#
#                   26                               27  \
# 0  Hệ điều hành (OS)  Loại Pin sử dụng (Battery Type)
# 1              iOS 6          Lithium Polymer (Li-Po)
#
#                          28                29                       30
# 0  Thời lượng sử dụng (giờ)  Trọng lượng (Kg)  Kích thước (Dimensions)
# 1                        10              0.66   241.2 x 185.7 x 9.4 mm
#
# [2 rows x 31 columns]

# %%
data = matchingSystem.pipelineMatching(df_origin)
# Out:
# name                	name                	1.0
# price               	price               	1.0
# url_img             	url_img             	1.0
# link                	link                	1.0

# %%
data.head()
# Out:
#                                  name  \
# 0  iPad 4 Wifi/4G 64GB Mới 95% -> 99%
# 1  iPad 2 Wifi/3G 16GB Mới 95% -> 99%
# 2  iPad 4 Wifi/4G 16GB Mới 95% -> 99%
# 3  iPad 3 Wifi/4G 16GB Mới 95% -> 99%
# 4     iPad 3 Wifi 16GB Mới 95% -> 99%
#
#                                                  url  ram  rom  \
# 0  http://tragopdidong.vn/ipad-4-wifi-4g-64gb-moi...  NaN  NaN
# 1  http://tragopdidong.vn/ipad-2-wifi-3g-16gb-moi...  NaN  NaN
# 2  http://tragopdidong.vn/ipad-4-wifi-4g-16gb-moi...  NaN  NaN
# 3  http://tragopdidong.vn/ipad-3-wifi-4g-16gb-moi...  NaN  NaN
# 4  http://tragopdidong.vn/ipad-3-wifi-16gb-moi-95...  NaN  NaN
#
#                                                price createdDate color status  \
# 0  \r\n                                        5,...         NaN   NaN    NaN
# 1  \r\n                                        2,...         NaN   NaN    NaN
# 2  \r\n                                        3,...         NaN   NaN    NaN
# 3  \r\n                                        2,...         NaN   NaN    NaN
# 4  \r\n                                        3,...         NaN   NaN    NaN
#
#                                              url_img
# 0  [http://tragopdidong.vn/img/h360/ipad-4-wifi-4...
# 1  [http://tragopdidong.vn/img/h360/ipad-2-wifi-3...
# 2  [http://tragopdidong.vn/img/h360/ipad-4-wifi-4...
# 3  [http://tragopdidong.vn/img/h360/ipad-3-wifi-4...
# 4  [http://tragopdidong.vn/img/h360/ipad-3-wifi-1...

# %%
newDf = preprocess.extractRamFromName(data)
newDf = preprocess.extractRomFromName(newDf)
newDf = preprocess.preprocessData(newDf, status=1)
# Out:
# 'float' object has no attribute 'replace'

# %%
newDf['store']='tragopdidong'

# %%
# data['ram'] = data['ram'].astype('int64')
# data['rom'] = data['rom'].astype('int64')
# data['price'] = data['price'].astype('int64')
# data['status'] = data['status'].astype('int64')

# %%
newDf.dtypes
# Out:
# name                   object
# url                    object
# ram                    object
# rom                    object
# price                  object
# createdDate    datetime64[ns]
# color                  object
# status                  int64
# url_img                object
# store                  object
# dtype: object

# %%
newDf.to_csv('../../datamatching/data/tgdd-ipad.csv')

# %%
newDf.head()
# Out:
#      name                                                url      ram rom  \
# 0  IPAD 4  http://tragopdidong.vn/ipad-4-wifi-4g-64gb-moi...  unknown  64
# 1  IPAD 2  http://tragopdidong.vn/ipad-2-wifi-3g-16gb-moi...  unknown  16
# 2  IPAD 4  http://tragopdidong.vn/ipad-4-wifi-4g-16gb-moi...  unknown  16
# 3  IPAD 3  http://tragopdidong.vn/ipad-3-wifi-4g-16gb-moi...  unknown  16
# 4  IPAD 3  http://tragopdidong.vn/ipad-3-wifi-16gb-moi-95...  unknown  16
#
#      price                createdDate    color  status  \
# 0  5298000 2022-12-26 19:57:29.204453  unknown       1
# 1  2368000 2022-12-26 19:57:29.204453  unknown       1
# 2  3468000 2022-12-26 19:57:29.204453  unknown       1
# 3  2868000 2022-12-26 19:57:29.204453  unknown       1
# 4  3050000 2022-12-26 19:57:29.204453  unknown       1
#
#                                              url_img         store
# 0  [http://tragopdidong.vn/img/h360/ipad-4-wifi-4...  tragopdidong
# 1  [http://tragopdidong.vn/img/h360/ipad-2-wifi-3...  tragopdidong
# 2  [http://tragopdidong.vn/img/h360/ipad-4-wifi-4...  tragopdidong
# 3  [http://tragopdidong.vn/img/h360/ipad-3-wifi-4...  tragopdidong
# 4  [http://tragopdidong.vn/img/h360/ipad-3-wifi-1...  tragopdidong

# %% [markdown]
# # Schema matching
