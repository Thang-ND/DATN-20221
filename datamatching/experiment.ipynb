# %%
import pandas as pd
import random
import glob
import numpy as np
import strsimpy
print('setup done!')
import hashlib
from tqdm import tqdm
from pymongo import MongoClient
# Out:
# setup done!

# %%
pd.set_option('display.max_colwidth', None)

# %%
client = MongoClient("mongodb+srv://winner:Mongodb2022@apple-hust.ngecy7x.mongodb.net/?retryWrites=true&w=majority")
database = 'Apple'
collection1 = 'Product_Search'
collection2 = 'Products'

# %%
db = client[database]
col_products = db[collection2]

# %%
len(list(col_products.find({})))
# Out:
# 5465

# %%
test = list(col_products.find({}))
test[0]
# Out:
# {'_id': ObjectId('63c014de303c669a9edb710f'),
#  'name': 'IPHONE 14 PRO MAX',
#  'url': 'https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626',
#  'ram': 6,
#  'rom': 128.0,
#  'price': 29790000,
#  'createdDate': '2023-01-10 20:58:07.383649',
#  'color': 'PURPLE',
#  'status': 0,
#  'url_img': 'unknown',
#  'store': '24hstore',
#  'id': '7760cef25f6a9dbe92772fba4897cada8e20c489abaddd7d73f6664d23b892c'}

# %%
df = pd.DataFrame.from_records(test)

# %%
df.head()
# Out:
#                         _id               name  \
# 0  63c014de303c669a9edb710f  IPHONE 14 PRO MAX
# 1  63c014de303c669a9edb7110  IPHONE 14 PRO MAX
# 2  63c014de303c669a9edb7111  IPHONE 14 PRO MAX
# 3  63c014de303c669a9edb7112  IPHONE 14 PRO MAX
# 4  63c014de303c669a9edb7113  IPHONE 14 PRO MAX
#
#                                                  url ram    rom     price  \
# 0  https://24hstore.vn/iphone-14-pro-max-moi/ipho...   6  128.0  29790000
# 1  https://24hstore.vn/iphone-14-pro-max-moi/ipho...   6  256.0  33290000
# 2  https://24hstore.vn/iphone-14-pro-max-moi/ipho...   6  512.0  39490000
# 3  https://24hstore.vn/iphone-14-pro-max-moi/ipho...   6    1.0  44990000
# 4  https://24hstore.vn/iphone-14-pro-max-moi/ipho...   6  128.0  29790000
#
#                   createdDate   color  status  url_img     store  \
# 0  2023-01-10 20:58:07.383649  PURPLE       0  unknown  24hstore
# 1  2023-01-10 20:58:07.383649  PURPLE       0  unknown  24hstore
# 2  2023-01-10 20:58:07.383649  PURPLE       0  unknown  24hstore
# 3  2023-01-10 20:58:07.383649  PURPLE       0  unknown  24hstore
# 4  2023-01-10 20:58:07.383649  YELLOW       0  unknown  24hstore
#
#                                                   id id_orgin list_id
# 0  7760cef25f6a9dbe92772fba4897cada8e20c489abaddd...      NaN     NaN
# 1  429e373ef6f16693d986321a1e52495b4180ffa365c262...      NaN     NaN
# 2  b839bb1caf3da2fd49c9b0fa2dd0915687c5caf8cf761e...      NaN     NaN
# 3  1d67737e5e67b5d49aa7b12ba9402f5cb475fcd62a5b62...      NaN     NaN
# 4  c6b687cc80466eae7ff9a4c11a929755c2d736a7c68db9...      NaN     NaN

# %%
df['color'].drop_duplicates().to_csv('res.csv')

# %%
color1 = ['ĐEN', 'TRẮNG', 'TÍM', 'ĐỎ', 'XANH LÁ', 'XANH', 'VÀNG', 'XANH DƯƠNG', 'THAN CHÌ',
    'HỒNG', 'BẠC', 'XANH RÊU', 'JETBLACK', 'XÁM', 'XANH DƯƠNG', 'CAM', 'DA XANH',
    'XANH BIỂN', 'VÀNG HỒNG', 'ĐEN MỜ', 'XANH ĐEN', 'ĐEN BÓNG', 'XANH NAVY', 'VÀNG ĐỒNG']
color2 = ['BLACK', 'WHITE', 'PURPLE', 'RED', 'GREEN', 'BLUE', 'YELLOW', 'BLUE', 'GRAPHITE',
            'PINK', 'SILVER', 'MOSS GREEN', 'JETBLACK', 'GRAY', 'BLUE', 'ORANGE', 'BLUE SKIN',
            'SEA BLUE', 'ROSE GOLD', 'BLACK', 'BLUE', 'BLACK', 'BLUE', 'YELLOW']
def processColor(df):
    for i in range(len(df)):
        for j in range(len(color1)):
            if color1[j] in df.loc[i, 'color'].upper():
                df.loc[i, 'color'] = color2[j]
                break
    return df

# %%
df_new = processColor(df)

# %%
df_new['color'].drop_duplicates().to_csv('res.csv')

# %%
df['rom'].drop_duplicates().to_csv('res.csv')

# %%
df['rom'].astype('float')

# %%
import re

# %%
df_obj = df.select_dtypes(['object'])

# %%
df_obj
# Out:
#                            _id               name  \
# 0     63c014de303c669a9edb710f  IPHONE 14 PRO MAX
# 1     63c014de303c669a9edb7110  IPHONE 14 PRO MAX
# 2     63c014de303c669a9edb7111  IPHONE 14 PRO MAX
# 3     63c014de303c669a9edb7112  IPHONE 14 PRO MAX
# 4     63c014de303c669a9edb7113  IPHONE 14 PRO MAX
# ...                        ...                ...
# 5460  63fcd08baeafb1bd8d4d699c      IPHONE 14 PRO
# 5461  63fcd08baeafb1bd8d4d69af          IPHONE 14
# 5462  63fcd08baeafb1bd8d4d69b9          IPHONE 14
# 5463  63fcd08baeafb1bd8d4d69d7          IPHONE 14
# 5464  63fcd08baeafb1bd8d4d69e2          IPHONE 14
#
#                                                                         url  \
# 0     https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626
# 1     https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626
# 2     https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626
# 3     https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626
# 4     https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626
# ...                                                                     ...
# 5460           https://www.viettablet.com/iphone-14-pro-1tb-chinh-hang-vn-a
# 5461             https://www.viettablet.com/iphone-14-512gb-chinh-hang-vn-a
# 5462             https://www.viettablet.com/iphone-14-512gb-chinh-hang-vn-a
# 5463        https://www.viettablet.com/iphone-14-plus-512gb-chinh-hang-vn-a
# 5464        https://www.viettablet.com/iphone-14-plus-512gb-chinh-hang-vn-a
#
#      ram    rom     price                 createdDate   color  url_img  \
# 0      6  128.0  29790000  2023-01-10 20:58:07.383649  PURPLE  unknown
# 1      6  256.0  33290000  2023-01-10 20:58:07.383649  PURPLE  unknown
# 2      6  512.0  39490000  2023-01-10 20:58:07.383649  PURPLE  unknown
# 3      6    1.0  44990000  2023-01-10 20:58:07.383649  PURPLE  unknown
# 4      6  128.0  29790000  2023-01-10 20:58:07.383649  YELLOW  unknown
# ...   ..    ...       ...                         ...     ...      ...
# 5460   6   1024  30590000  2023-02-27 22:40:54.575000     VNA  unknown
# 5461   6    512  19490000  2023-02-27 22:40:54.575000     LLA  unknown
# 5462   6    512  20590000  2023-02-27 22:40:54.575000     VNA  unknown
# 5463   6    512  20390000  2023-02-27 22:40:54.575000     LLA  unknown
# 5464   6    512  21190000  2023-02-27 22:40:54.575000     VNA  unknown
#
#            store  \
# 0       24hstore
# 1       24hstore
# 2       24hstore
# 3       24hstore
# 4       24hstore
# ...          ...
# 5460  viettablet
# 5461  viettablet
# 5462  viettablet
# 5463  viettablet
# 5464  viettablet
#
#                                                                     id  \
# 0      7760cef25f6a9dbe92772fba4897cada8e20c489abaddd7d73f6664d23b892c
# 1      429e373ef6f16693d986321a1e52495b4180ffa365c2623a1cd9a66bbd6d8df
# 2      b839bb1caf3da2fd49c9b0fa2dd0915687c5caf8cf761e21b6cac2e34daebfa
# 3     1d67737e5e67b5d49aa7b12ba9402f5cb475fcd62a5b6288671ac0be49178c92
# 4         c6b687cc80466eae7ff9a4c11a929755c2d736a7c68db9d9171aefc8ebfd
# ...                                                                ...
# 5460   ae793db426df984e09239cbc450f7132b5b9e84f4c3d73922a4a0bbc366d4b3
# 5461    57f222104184dde62dfda17bb049a9312170365320214896a165c0a8164d25
# 5462  dd5bc2b461548be657116ae9f8df4927ee833bb182b6ae99ae52539498231668
# 5463     98207bf78176de7331426e18f6fd8be435bde8a4531ce7fd50556f4dad1b8
# 5464   59649a251e839f55ba4b8edac38e2ca72a33c757fc0323e85c314fbd0b06775
#
#      id_orgin list_id
# 0         NaN     NaN
# 1         NaN     NaN
# 2         NaN     NaN
# 3         NaN     NaN
# 4         NaN     NaN
# ...       ...     ...
# 5460      NaN     NaN
# 5461      NaN     NaN
# 5462      NaN     NaN
# 5463      NaN     NaN
# 5464      NaN     NaN
#
# [5465 rows x 13 columns]

# %%
df['rom'] = df_obj.rom.apply(lambda x: re.sub(r'\D', '', x).strip())

# %%
df.head()
# Out:
#                         _id               name  \
# 0  63c014de303c669a9edb710f  IPHONE 14 PRO MAX
# 1  63c014de303c669a9edb7110  IPHONE 14 PRO MAX
# 2  63c014de303c669a9edb7111  IPHONE 14 PRO MAX
# 3  63c014de303c669a9edb7112  IPHONE 14 PRO MAX
# 4  63c014de303c669a9edb7113  IPHONE 14 PRO MAX
#
#                                                                      url ram  \
# 0  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
# 1  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
# 2  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
# 3  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
# 4  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
#
#      rom     price                 createdDate   color  status  url_img  \
# 0  128.0  29790000  2023-01-10 20:58:07.383649  PURPLE       0  unknown
# 1  256.0  33290000  2023-01-10 20:58:07.383649  PURPLE       0  unknown
# 2  512.0  39490000  2023-01-10 20:58:07.383649  PURPLE       0  unknown
# 3    1.0  44990000  2023-01-10 20:58:07.383649  PURPLE       0  unknown
# 4  128.0  29790000  2023-01-10 20:58:07.383649  YELLOW       0  unknown
#
#       store                                                                id
# 0  24hstore   7760cef25f6a9dbe92772fba4897cada8e20c489abaddd7d73f6664d23b892c
# 1  24hstore   429e373ef6f16693d986321a1e52495b4180ffa365c2623a1cd9a66bbd6d8df
# 2  24hstore   b839bb1caf3da2fd49c9b0fa2dd0915687c5caf8cf761e21b6cac2e34daebfa
# 3  24hstore  1d67737e5e67b5d49aa7b12ba9402f5cb475fcd62a5b6288671ac0be49178c92
# 4  24hstore      c6b687cc80466eae7ff9a4c11a929755c2d736a7c68db9d9171aefc8ebfd

# %%
len(df.drop_duplicates())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/thangnd/Documents/20221/DATN-20221/datamatching/experiment.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/thangnd/Documents/20221/DATN-20221/datamatching/experiment.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> len(df.drop_duplicates())
#
# File ~/anaconda3/envs/crawler/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/crawler/lib/python3.10/site-packages/pandas/core/frame.py:6063, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6061 inplace = validate_bool_kwarg(inplace, "inplace")
#    6062 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6063 duplicated = self.duplicated(subset, keep=keep)
#    6065 result = self[-duplicated]
#    6066 if ignore_index:
#
# File ~/anaconda3/envs/crawler/lib/python3.10/site-packages/pandas/core/frame.py:6200, in DataFrame.duplicated(self, subset, keep)
#    6197     raise KeyError(diff)
#    6199 vals = (col.values for name, col in self.items() if name in subset)
# -> 6200 labels, shape = map(list, zip(*map(f, vals)))
#    6202 ids = get_group_index(
#    6203     labels,
#    6204     # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6208     xnull=False,
#    6209 )
#    6210 result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~/anaconda3/envs/crawler/lib/python3.10/site-packages/pandas/core/frame.py:6173, in DataFrame.duplicated.<locals>.f(vals)
#    6172 def f(vals) -> tuple[np.ndarray, int]:
# -> 6173     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6174     return labels.astype("i8", copy=False), len(shape)
#
# File ~/anaconda3/envs/crawler/lib/python3.10/site-packages/pandas/core/algorithms.py:761, in factorize(values, sort, na_sentinel, size_hint)
#     758     else:
#     759         na_value = None
# --> 761     codes, uniques = factorize_array(
#     762         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     763     )
#     765 if sort and len(uniques) > 0:
#     766     uniques, codes = safe_sort(
#     767         uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     768     )
#
# File ~/anaconda3/envs/crawler/lib/python3.10/site-packages/pandas/core/algorithms.py:563, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     560 hash_klass, values = get_data_algo(values)
#     562 table = hash_klass(size_hint or len(values))
# --> 563 uniques, codes = table.factorize(
#     564     values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     565 )
#     567 codes = ensure_platform_int(codes)
#     568 return codes, uniques
#
# File pandas/_libs/hashtable_class_helper.pxi:5396, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:5310, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
df.head()
# Out:
#                         _id               name  \
# 0  63c014de303c669a9edb710f  IPHONE 14 PRO MAX
# 1  63c014de303c669a9edb7110  IPHONE 14 PRO MAX
# 2  63c014de303c669a9edb7111  IPHONE 14 PRO MAX
# 3  63c014de303c669a9edb7112  IPHONE 14 PRO MAX
# 4  63c014de303c669a9edb7113  IPHONE 14 PRO MAX
#
#                                                                      url ram  \
# 0  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
# 1  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
# 2  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
# 3  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
# 4  https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626   6
#
#      rom     price                 createdDate   color  status  url_img  \
# 0  128.0  29790000  2023-01-10 20:58:07.383649  PURPLE       0  unknown
# 1  256.0  33290000  2023-01-10 20:58:07.383649  PURPLE       0  unknown
# 2  512.0  39490000  2023-01-10 20:58:07.383649  PURPLE       0  unknown
# 3    1.0  44990000  2023-01-10 20:58:07.383649  PURPLE       0  unknown
# 4  128.0  29790000  2023-01-10 20:58:07.383649  YELLOW       0  unknown
#
#       store                                                                id  \
# 0  24hstore   7760cef25f6a9dbe92772fba4897cada8e20c489abaddd7d73f6664d23b892c
# 1  24hstore   429e373ef6f16693d986321a1e52495b4180ffa365c2623a1cd9a66bbd6d8df
# 2  24hstore   b839bb1caf3da2fd49c9b0fa2dd0915687c5caf8cf761e21b6cac2e34daebfa
# 3  24hstore  1d67737e5e67b5d49aa7b12ba9402f5cb475fcd62a5b6288671ac0be49178c92
# 4  24hstore      c6b687cc80466eae7ff9a4c11a929755c2d736a7c68db9d9171aefc8ebfd
#
#   id_orgin list_id
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN

# %%
df = df.drop('id_orgin', axis=1)
df = df.drop('list_id', axis=1)
df.columns

# %%
levenshtein  = strsimpy.NormalizedLevenshtein()

def levenshtein_score(x,y):
    if (x=='unknown' or y =='unknown'):
        return 1
    return 1 - levenshtein.distance(x,y)

def difference_score(x,y):
    if (x=='unknown' or y =='unknown'):
        return 1
    return 1 if x==y else 0

def clust_filter(arr):
    flag = [False]*len(arr)
    cluster = []
    for i in tqdm(range(0,len(arr)-1)):
        if flag[i]==False:
            list_id = []
            list_id.append(arr[i][11])
            for j in range(i + 1, len(arr)):
                if flag[j]==False:
                    name = difference_score(arr[i][1],arr[j][1])
                    ram = difference_score(arr[i][3],arr[j][3])
                    rom = difference_score(arr[i][4],arr[j][4])
                    color = levenshtein_score(arr[i][7],arr[j][7])
                    #status = difference_score(arr[i][7], arr[j][7])
                    score = 0.6 * name + 0.1 * ram + 0.2 * rom + 0.1 * color
                    if score >= 0.95:
                        flag[j] = True
                        list_id.append(arr[j][11])
            list_id = list(set(list_id))
            arr[i].append(list_id)
            cluster.append(arr[i])
            
    return cluster

# %%
arr = df.values.tolist()

# %%
arr[0]
# Out:
# [ObjectId('63c014de303c669a9edb710f'),
#  'IPHONE 14 PRO MAX',
#  'https://24hstore.vn/iphone-14-pro-max-moi/iphone-14-pro-max-1tb-p6626',
#  6,
#  128.0,
#  29790000,
#  '2023-01-10 20:58:07.383649',
#  'PURPLE',
#  0,
#  'unknown',
#  '24hstore',
#  '7760cef25f6a9dbe92772fba4897cada8e20c489abaddd7d73f6664d23b892c']

# %%
cluster = clust_filter(arr)
# Out:
# 100%|██████████| 5464/5464 [00:45<00:00, 120.16it/s]

# %%
len(cluster)
# Out:
# 1357

# %%
rand_test = random.choice(cluster)
list_id = rand_test[12]

# %%
rand_test
# Out:
# [ObjectId('63d13abb71bdce7a2488d417'),
#  'IPHONE 13 PRO',
#  'http://tragopdidong.vn/iphone-13-pro-256g-quoc-te-moi-100.html',
#  6,
#  '256',
#  '21868000',
#  datetime.datetime(2023, 1, 25, 21, 20, 4, 650000),
#  'unknown',
#  1,
#  [],
#  'tragopdidong',
#  nan,
#  ['fceaa48ec731d840e2b29c3514448327204555103b231c53807d69ef27d',
#   '94676fe687185d28a977f45217d93a91ad99e864f69de5f8a2fbdc065c144',
#   '90fe83b19675ed375443ac8612af937f88d55cb9ca7d2ef374ed9b43eb7ba91',
#   'a0aa19afeeb62b2d4f3c2d1f2cfa7298536a41e164795c3abc28bd48a7ac',
#   'bee8f69684aaccef435e748c930d9429f2024abd5d4e2503add585d6a17b',
#   '9cf21e9a8ed223104c29dbccd51c1082a69101409ae8b3fc7614a21fee5',
#   'ee5c122746e56c4f3c820515a8ddac5f24e8ab971d361d748949045388e11',
#   'dace95d03453c7e0265a2b3ec1a61d843a6b794b501d901bc6cbdc4fc1ce172',
#   'dc82dc351c1c3e87fc128e18cfb2b29a3131f7e29a8b5cfdff26eeced96c43',
#   'e91966f72791d2c121bd747f1a4bc56ec2fa54182901dc8d714dc09a853be8',
#   '75a7eb68d6d9811b1163d6266da154227e387d45a89c389d45d7dfcf37b69',
#   'c2f753c7cfdaffe3d987d4eb59c94df35c3696115cfdc8b9436459bdf2390f9',
#   '6912257dee45bbcf545f5cbc6852fbd1630d0d4935256909b3f4bffab7a6ed',
#   'e348a14070ec7bc0cf8be165e1bb125fdbb2a72e5511d2fad49cb8de41ada67',
#   '8f4c1a421996080e65f84846fbe686cba32e97bdc30a17b44d562806ff2a879',
#   'bb6731916aeeb46ff07abec7c9cbca4e79623ef9c9126c8f1a5e32018937671',
#   'c216095a1c85b2f47f63c7ea2902cf9c798766f92adb4c03dad4324619810f0',
#   nan,
#   '617de9c9e177a6d746af41984c0f64811fe7dffd34a6f3c2f430f489a26ba2',
#   '4c49aae9f1c9a2b1ad398dca39f6ddb9e4257642e236d808d6f883dbf47',
#   '689152b6a97e2387e8ea54e57f9553cb6343e4c736d57d94a77469d8880942f',
#   '9cf69a63fbf139c03126bf7d49196dec155ce9c8259f73c3f46ce1894747778',
#   '7f532c302fba8fd1cdb2fd0ef37b3f1f88f16a9efa2e6b866ae1fc75df77c6d',
#   'e756ec882f1c27645a9040837adc7056c886659f7c85789d8e275cd68208d',
#   'd2fee49040ad6ab7d68bb3cc158b35efb9a40992a6f39fbd319a82d99c48bb',
#   '7e8fc8546c3bc1d82b979640f914e8acd5547464f64713be3ecbf2983e2246',
#   'aa83a84726afa3d2df2e83b78b6532eec3836a9f7bee9f343f4bef1fd79fbf8',
#   'c022e77c1e3c69d5438f12e3d764132e84196d8f6dd2cfee895d1b6747a649d4',
#   'f796374110f6191871956ec4bd7b5742d7f1b7e5fae5cfdd28a3b8ce3af924a4',
#   '4bedebadfaffdc53f6a5335d7126139271776ce517ceccd80d744af3aec825a',
#   '6ccc4481aaa3c8b9d586e54fb10f0b4589e8f913b8461b1dbd52b68ddf1c978',
#   'e69dd11ea2d68b22a5bd159a127f7bd48dcfab5eb1e7ca3b4bba899794c525d7',
#   '323c208e3febe8e0d259bd6253a6af99bcf859383f5f47f0c8db8b3d7ca88dc',
#   '31ee638ec647af82aa8d0201ff6ca84fe4d61acaf57953052403fdd59be571',
#   '7f22945046c6681cdbfea74dcda1f5fcb76e5b7ac1bd848247c37e6ca74c224',
#   '5c9ac12bf4bcdf13a237d831c3ccdfbde87b286069b22e66fba4ba9416e585f3',
#   'dfe3e722dd7ad3dc0e94c8c2b50db969aeb305194741d26ce91853858542d5f',
#   '7a6064ce22402ce679377bd97886ce12d8ac4ea199cba08dc1d78f13ac555',
#   '2eac8fb5668fc3121862b2e3e262ca7f143bc027aad3cee834552f3b4990cc',
#   '1c611023774993901fd315758fc8edcafe42b856594af8d865d365d8f1fb36',
#   '226279be881ca7266fb15cb30b9634cca6c964f60795ae5026aa5f568b82',
#   'cccaac639b123c1a61492279a1214cc80608c3081729494787eeffae30d87f',
#   'f16a1bf0e756fbec1456ca80ab440b09aa33fe591fb3ec61726218c6449d37',
#   'e6bb79f1717a95c0b79d92dd623922ef6d890cd0f22b5fee3bdefa5e215d27',
#   '1e7ba418ddf957c4b58b52f5e7cb935b5ff832e305ed29d67196cd9d1c853',
#   '4ee8efc2b76a78e5cb5a2e289e8961bfa2597a65b60b09398e69db0439f8294',
#   '16194348b8d96ffa99a986837f29cc3554e359fee153b17d9bd362ab50d71add',
#   '58fb42e5c28671716317b1e19e134f0eb1be58d3cb37f28a131732d0ee56c3',
#   '249cc3e9a53755b86a7f448316813bbbd759ec452b1606cb6c9e4522dd2f',
#   'babad01435388fe41e9fccfba4bbadab35de61bcca4529ef2c5f5d5bd3b6c',
#   '1399943770e5aa684771b41edaf81a4148d3fae46d88134b55f61f094b0d8f2',
#   'c5c727d1e2f7041ce86952e3a4371b4712a9967f94367bd82b71a75bf2f7ea']]

# %%
len(list_id)
# Out:
# 52

# %%
df[df['id'].isin(list_id)]
# Out:
#                            _id           name  \
# 2559  63d1319dbfcf85d5fa989049      IPHONE 11
# 2560  63d131ecbfcf85d5fa98904a  IPHONE 8 PLUS
# 2561  63d13238bfcf85d5fa98904b  IPHONE 8 PLUS
# 2562  63d13295bfcf85d5fa98904c       IPHONE 8
# 2563  63d132f7bfcf85d5fa98904d       IPHONE X
# ...                        ...            ...
# 5118  63da5a3b15a8deae0a5f9964  IPHONE 13 PRO
# 5402  63fcd083aeafb1bd8d4d60d2  IPHONE 13 PRO
# 5403  63fcd083aeafb1bd8d4d60f0  IPHONE 13 PRO
# 5409  63fcd085aeafb1bd8d4d62f8  IPHONE 13 PRO
# 5410  63fcd085aeafb1bd8d4d632b  IPHONE 13 PRO
#
#                                                                           url  \
# 2559               http://tragopdidong.vn/iphone-11-128g-quoc-te-moi-100.html
# 2560          http://tragopdidong.vn/iphone-8-plus-64g-quoc-te-moi-95-99.html
# 2561         http://tragopdidong.vn/iphone-8-plus-256g-quoc-te-moi-95-99.html
# 2562               http://tragopdidong.vn/iphone-8-64g-quoc-te-moi-95-99.html
# 2563                http://tragopdidong.vn/iphone-x-256g-quoc-te-moi-100.html
# ...                                                                       ...
# 5118                      https://www.xtmobile.vn/iphone-13-pro-256gb-likenew
# 5402           https://www.viettablet.com/iphone-13-pro-256gb-chinh-hang-vn-a
# 5403           https://www.viettablet.com/iphone-13-pro-256gb-chinh-hang-vn-a
# 5409  https://www.viettablet.com/iphone-13-pro-256gb-chinh-hang-vn-a-like-new
# 5410  https://www.viettablet.com/iphone-13-pro-256gb-chinh-hang-vn-a-like-new
#
#      ram  rom     price                 createdDate    color  status  \
# 2559   4  128  13468000  2023-01-25 20:38:54.526000  unknown       1
# 2560   2   64   3168000  2023-01-25 20:38:54.526000  unknown       1
# 2561   2  256   4068000  2023-01-25 20:38:54.526000  unknown       1
# 2562   2   64   2168000  2023-01-25 20:38:54.526000  unknown       1
# 2563   3  256  11650000  2023-01-25 20:38:54.526000  unknown       1
# ...   ..  ...       ...                         ...      ...     ...
# 5118   6  256  20590000  2023-02-05 21:44:21.356000     BLUE       1
# 5402   6  256  26590000  2023-02-27 22:40:54.575000    BLACK       1
# 5403   6  256  26690000  2023-02-27 22:40:54.575000   YELLOW       1
# 5409   6  256  20590000  2023-02-27 22:40:54.575000    WHITE       1
# 5410   6  256  19590000  2023-02-27 22:40:54.575000     GRAY       1
#
#                                                                                                 url_img  \
# 2559  [http://tragopdidong.vn/img/h360/moi-99-22.jpg, http://tragopdidong.vn/img/w60/h95/moi-99-22.jpg]
# 2560                                                                                                 []
# 2561                                                                                                 []
# 2562                                                                                                 []
# 2563                                                                                                 []
# ...                                                                                                 ...
# 5118                                                                                            unknown
# 5402                                                                                            unknown
# 5403                                                                                            unknown
# 5409                                                                                            unknown
# 5410                                                                                            unknown
#
#              store  \
# 2559  tragopdidong
# 2560  tragopdidong
# 2561  tragopdidong
# 2562  tragopdidong
# 2563  tragopdidong
# ...            ...
# 5118      xtmobile
# 5402    viettablet
# 5403    viettablet
# 5409    viettablet
# 5410    viettablet
#
#                                                                     id
# 2559                                                               NaN
# 2560                                                               NaN
# 2561                                                               NaN
# 2562                                                               NaN
# 2563                                                               NaN
# ...                                                                ...
# 5118    1c611023774993901fd315758fc8edcafe42b856594af8d865d365d8f1fb36
# 5402  f796374110f6191871956ec4bd7b5742d7f1b7e5fae5cfdd28a3b8ce3af924a4
# 5403      a0aa19afeeb62b2d4f3c2d1f2cfa7298536a41e164795c3abc28bd48a7ac
# 5409   689152b6a97e2387e8ea54e57f9553cb6343e4c736d57d94a77469d8880942f
# 5410   9cf69a63fbf139c03126bf7d49196dec155ce9c8259f73c3f46ce1894747778
#
# [141 rows x 12 columns]

# %%
df[df['name']=='IPHONE SE 3']
