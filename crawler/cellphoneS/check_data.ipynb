# %%
import pandas as pd

# %%
df = pd.read_json('./data.json')

# %%
df
# Out:
#                                           name    color        price  \
# 0     iPhone 13 Pro Max 1TB I Chính hãng VN/A   Xanh lá  36.990.000₫
# 1     iPhone 13 Pro Max 1TB I Chính hãng VN/A   Xanh lá  36.990.000₫
# 2     iPhone 13 Pro Max 1TB I Chính hãng VN/A   Xanh lá  36.490.000₫
# 3     iPhone 13 Pro Max 1TB I Chính hãng VN/A   Xanh lá  36.990.000₫
# 4     iPhone 13 Pro Max 1TB I Chính hãng VN/A   Xanh lá  36.490.000₫
# ..                                         ...      ...          ...
# 455        iPhone 14 128GB  | Chính hãng VN/A        Đỏ  20.990.000₫
# 456        iPhone 14 128GB  | Chính hãng VN/A        Đỏ  21.790.000₫
# 457        iPhone 14 128GB  | Chính hãng VN/A        Đỏ  21.390.000₫
# 458        iPhone 14 128GB  | Chính hãng VN/A        Đỏ  21.799.000₫
# 459        iPhone 14 128GB  | Chính hãng VN/A        Đỏ  21.790.000₫
#
#                                                    url
# 0    https://cellphones.com.vn/iphone-13-pro-max-1t...
# ...
